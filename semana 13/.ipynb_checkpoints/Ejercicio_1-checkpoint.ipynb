# %% [markdown]
# # Ejecicio1 Creado por Jesus Antonio Sanchez Garcia

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#se generan 20 puntos aleatorios
x=np.random.rand(20)
y=np.random.rand(20)
plt.scatter(x,y)

# %%
for i in range(0,200):
    y=(0.5+(np.sin(i)))
    x=(0.5+(np.cos(i)))
    plt.scatter(x,y,color='red')

# %%
for i in range(0,20):
    x=np.random.rand(20)
    y=np.random.rand(20)
    z=np.array([x,y])#se crea el arreglo
    h=z[0,i]
    k=z[1,i]
    plt.scatter(x,y,color='green')
    if i%2==0:#imprimir donde i sea un numero par
            for j in range(0,100):
                y=((0.1)*np.sin(j))
                x=((0.1)*np.cos(j))
                plt.scatter(x+h,y+k,color='blue')
