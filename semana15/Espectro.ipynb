# %%
import matplotlib.pyplot as plt #creado por jesus antonio sanchez garcia
import numpy as np
import scipy.constants as cont
# %matplotlib inline

# %%
point=np.loadtxt('IRFC.txt').T
#los datos se leeran del archivo IRFC.txt con el comando np.loadtxt
np.shape(point)
# Out:
# (5L, 43L)

# %%
x=point[0]
y=point[1]

# %%
plt.scatter(x,y)#grafica de puntos
plt.grid()

# %%
k=cont. Boltzmann
h=cont. Planck
c=cont. c #se añaden las constantes

# %%
print (h,k,c)#valor de las constantes
# Out:
# (6.62607004e-34, 1.38064852e-23, 299792458.0)

# %%
point=np.loadtxt('IRFC.txt')

# %%
n1=point[:,0:1]
n2=point[:,1:2]
n3=point[:,3:4]

# %%
plt.errorbar(n1,n2,n3,color= 'green')
plt.title("Espectro de la radiacion de fondo de microondas")
# Out:
# Text(0.5,1,'Espectro de la radiacion de fondo de microondas')

# %%
def I(v,T): #definicion de funcion
    S=(((h*v**3)/(c**2))*(1/np.exp((h*v)/(k*T))-1)) #1 Jy =10^-26 W•m^-2•Hz
    return S
